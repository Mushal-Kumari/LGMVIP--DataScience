# %%
import cv2
import matplotlib.pyplot as plt

# %%
image=cv2.imread("flower.jpg")
print('Original Dimensions : ',image.shape)
scale_percent = 10
width = int(image.shape[1] * scale_percent / 100)
height = int(image.shape[0] * scale_percent / 100)
dim = (width, height)
resized = cv2.resize(image, dim, interpolation = cv2.INTER_AREA)
print('Resized Dimensions : ',resized.shape)
#plt.imshow(resized)
#plt.show()
cv2.imshow("Flower",resized)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Original Dimensions :  (5760, 3840, 3)
# Resized Dimensions :  (576, 384, 3)

# %% [markdown]
# ![Screenshot%202022-07-03%20205218.jpg](attachment:Screenshot%202022-07-03%20205218.jpg)

# %%
gray_image=cv2.cvtColor(resized,cv2.COLOR_BGR2GRAY)
cv2.imshow("Newflower", gray_image)
cv2.waitKey(0)
#plt.imshow(gray_image)
#plt.show()
# Out:
# -1

# %% [markdown]
# ![Screenshot%202022-07-03%20205426.jpg](attachment:Screenshot%202022-07-03%20205426.jpg)

# %%
inverted_image=255-gray_image
cv2.imshow("Inverted", inverted_image)
cv2.waitKey()
# Out:
# -1

# %% [markdown]
# ![inverted_image.jpeg](attachment:inverted_image.jpeg)

# %%
blurred=cv2.GaussianBlur(inverted_image,(21,21),0)
cv2.imshow("blurred_image",blurred)
cv2.waitKey()
# Out:
# -1

# %% [markdown]
# ![Screenshot%202022-07-03%20210440.jpg](attachment:Screenshot%202022-07-03%20210440.jpg)

# %%
inverted_blurred=255-blurred
pencil_sketch=cv2.divide(gray_image,inverted_blurred,scale=256.0)
cv2.imshow("Sketch",pencil_sketch)
cv2.waitKey(0)

# %% [markdown]
# ![Screenshot%202022-07-03%20210923.jpg](attachment:Screenshot%202022-07-03%20210923.jpg)
